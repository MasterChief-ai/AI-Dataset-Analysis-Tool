# %%
pip install flask
# Out:
# ...
#
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
#    ---------------------------------------- 0/5 [werkzeug]
# ...

# %%
pip install fpdf
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40770 sha256=c0006036a545b16b2595d699cd7b343dd4a0f24ea27bbd4356a851c821d916f0
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\65\4f\66\bbda9866da446a72e206d6484cd97381cbc7859a7068541c36
# Successfully built fpdf
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pdfkit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install config
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-surprise
# Out:
# ...
#   Using cached scikit_surprise-1.1.4.tar.gz (154 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build scikit-surprise
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for scikit-surprise (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [155 lines of output]
#       C:\Users\user\AppData\Local\Temp\pip-build-env-cnwkomx3\overlay\Lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:82: SetuptoolsDeprecationWarning: `project.license` as a TOML table is deprecated
#       !!
#
#               ********************************************************************************
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
